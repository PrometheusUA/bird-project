# %%
import sys
sys.path.append('../')

import torch
import librosa

import matplotlib.pyplot as plt

from ml_base.model import BaselineBirdClassifier

# %%
import os    
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
audio, sr = librosa.load('../data/test-sample.ogg', sr=None)
audio2, sr = librosa.load('../data/test-sample2.ogg', sr=None)

# %%
model = BaselineBirdClassifier(491, sr)

# %%
plt.figure(figsize=(4, 2), dpi=120)
plt.imshow(model(torch.tensor(audio), return_spec=True)[0], aspect='auto')
plt.show()

# %%
plt.figure(figsize=(4, 2), dpi=120)
plt.imshow(model(torch.tensor(audio2), return_spec=True)[0], aspect='auto')
plt.show()

# %%
model(torch.tensor(audio), return_spec=True)[0].size()
# Out:
# torch.Size([64, 3419])

# %%
model(torch.tensor(audio)).size()
# Out:
# torch.Size([1, 491])
